# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from lib.dataset_utils import *
from sklearn.preprocessing import MultiLabelBinarizer
import seaborn as sns
import os
from transformers import BertTokenizer

# %%
train_df, val_df, test_df = load_dataset(DatasetEnum.TwitterData, k_hot_encode=True)
label_names = train_df.columns[1:]

# %% [markdown]
# ### Removing links and pictures or other non insteresting tokens

# %% [markdown]
# The problem here is that links appear as very different sequences of tokens, so we will proceed step by step

# %%
train_df[train_df["text"].str.contains(r"(?: href|http|(?: ^|\b)www(?: $|\b))", regex=True)]
# Out:
#                                                     text  anger  fear  joy  \
# 125    i feel they are pretty safe on my blog img src...      0     0    1
# 323    i stopped feeling so exhausted a href http pro...      0     0    0
# 462                  i feel so dazed a href http twitter      0     0    0
# 866    i feel unwelcome at work sometimes and think p...      0     0    0
# 967                         i a href http feeling groggy      0     0    0
# ...                                                  ...    ...   ...  ...
# 15344  i feel more confident already a href http john...      0     0    1
# 15518  i feel honoured to be asked thanks a href http...      0     0    1
# 15732  i feel like it was just a title mimm fall insp...      0     0    1
# 15779  i cant always identify with peoples struggles ...      0     0    0
# 15784  i get the added bonus of feeling superior and ...      0     0    1
#
#        love  sadness  surprise
# 125       0        0         0
# 323       0        1         0
# 462       0        0         1
# 866       0        1         0
# 967       0        1         0
# ...     ...      ...       ...
# 15344     0        0         0
# 15518     0        0         0
# 15732     0        0         0
# 15779     0        1         0
# 15784     0        0         0
#
# [201 rows x 7 columns]

# %% [markdown]
# these seems to be useful tokens to identify links or other data added to tweets
# - script
# - title bookmark
# - img
# - src
# - href
# - a (unfortunately)
# - http
# - nofollow

# %% [markdown]
# they always appear from one point till the end of the tokens of any record, so the important part is to understand where to split

# %%
occ = train_df[train_df["text"].str.contains(r"(?: nofollow)", regex=True)]
occ
# Out:
#                                                     text  anger  fear  joy  \
# 4966   i feel horrible about wanting sonipro amp sour...      0     0    0
# 7195   i i feel for you rel nofollow add to delicious...      0     0    1
# 8153   i feel like an idiot around my friends target ...      0     0    0
# 9268   i feel the earth move tribute to carole king k...      0     0    0
# 9501   i feel summer session title bookmark at digg r...      0     0    0
# 9527   i sound feeling ballroom cd rel nofollow targe...      0     0    0
# 13275  i feel a change coming espa a hd target blank ...      0     0    0
# 15305  i feel that i shouldnt be his back up a rel no...      0     0    0
#
#        love  sadness  surprise
# 4966      0        1         0
# 7195      0        0         0
# 8153      0        1         0
# 9268      0        1         0
# 9501      0        1         0
# 9527      0        1         0
# 13275     0        1         0
# 15305     0        1         0

# %% [markdown]
# in this sample, a is always used to start metadata

# %%
# cut sentences from the specified tokens
tok_ids = train_df["text"].str.contains(r"(?: (?: ^|\b)nofollow(?: $|\b))", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('a').str[0]
tok_ids = train_df["text"].str.contains(r"(?: (?: ^|\b)nofollow(?: $|\b))", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('rel').str[0]
tok_ids = train_df["text"].str.contains(r"(?: (?: ^|\b)nofollow(?: $|\b))", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('target').str[0]

# %%
occ = train_df[train_df["text"].str.contains(r"(?: \bscript\b)", regex=True)]
occ
# Out:
#                                                     text  anger  fear  joy  \
# 3496   im feeling the moxie fab love cath script src ...      0     0    1
# 11750  im happy to have finished the script s its goo...      0     0    0
# 12033  i just have a weird feeling that there was not...      0     0    1
#
#        love  sadness  surprise
# 3496      0        0         0
# 11750     0        1         0
# 12033     0        0         0

# %%
tok_ids = train_df["text"].str.contains(r"(?: script)", regex=True)
tok_ids[11750] = False
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('script').str[0]

# %%
occ = train_df[train_df["text"].str.contains(r"(?: img)", regex=True)]
occ
# Out:
#                                                     text  anger  fear  joy  \
# 125    i feel they are pretty safe on my blog img src...      0     0    1
# 1439   i feel fearless janelle mon e elle canada febr...      0     0    1
# 1542   i feel tat all of us in this world are clever ...      0     0    1
# 1726   i could just feel the joy rage coming at me fo...      0     0    1
# 2031   i use this day and night and sometimes when i ...      0     0    0
# 2279   i never feel fucked the week after i used some...      1     0    0
# 2561   i apologize to all the ppl i dragged along wit...      0     0    0
# 2754                 i feel really joyful img src http s      0     0    1
# 4975   i feel more adventurous willing to take risks ...      0     0    1
# 5300   i feel studying and doing homework again after...      0     0    0
# 6570   i feel cdm flac custodes title alibi how much ...      0     0    1
# 7185   i feels so proud of my self img alt onion head...      0     0    1
# 7287      i keep feeling weird sensations img src http s      0     1    0
# 7709   i feel that karma punished me because i don t ...      0     0    0
# 8606   i feel empty inside iphone wallpaper mobile wa...      0     0    0
# 8629   i am not desperate for a job and don t really ...      0     0    0
# 8995    i was feeling rather horny though img src http s      0     0    0
# 9269   i feel me better cuz i listen to this song img...      0     0    1
# 9510   i feel annoyed img class aligncenter size full...      1     0    0
# 11947  i feel stupid img width height src http voices...      0     0    0
# 11984  i feel greedy about my work img height src htt...      1     0    0
# 12024  i had an epiphany that i should feel proud of ...      0     0    1
# 12634  i feel ignored annotation title google bookmar...      0     0    0
# 12925          i feel so ugly and ashamed img src http s      0     0    0
# 13815  i recommend the jasmine green tea teapot servi...      0     0    1
# 13846  i feel more adventurous willing to take risks ...      0     0    1
# 13886  i am still feeling unhappy and upset about the...      0     0    0
# 14121            i say no i feel guilty img src http var      0     0    0
# 14683  i feel perfect with you comments img src http ...      0     0    1
# 15175  i m tryin my level best be a gud pal but i can...      1     0    0
#
#        love  sadness  surprise
# 125       0        0         0
# 1439      0        0         0
# 1542      0        0         0
# 1726      0        0         0
# 2031      0        1         0
# 2279      0        0         0
# 2561      0        1         0
# 2754      0        0         0
# 4975      0        0         0
# 5300      0        1         0
# 6570      0        0         0
# 7185      0        0         0
# 7287      0        0         0
# 7709      0        1         0
# 8606      0        1         0
# 8629      0        0         1
# 8995      1        0         0
# 9269      0        0         0
# 9510      0        0         0
# 11947     0        1         0
# 11984     0        0         0
# 12024     0        0         0
# 12634     0        1         0
# 12925     0        1         0
# 13815     0        0         0
# 13846     0        0         0
# 13886     0        1         0
# 14121     0        1         0
# 14683     0        0         0
# 15175     0        0         0

# %%
tok_ids = train_df["text"].str.contains(r"(?: img)", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('img').str[0]
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('annotation').str[0]

# %%
occ = train_df[train_df["text"].str.contains(r"(?: title bookmark)", regex=True)]
occ
# Out:
# Empty DataFrame
# Columns: [text, anger, fear, joy, love, sadness, surprise]
# Index: []

# %%
tok_ids = train_df["text"].str.contains(r"(?: title bookmark)", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('title bookmark').str[0]

# %%
occ = train_df[train_df["text"].str.contains(r"(?: src(?: url)?)", regex=True)]
occ
# Out:
#                                                     text  anger  fear  joy  \
# 5156   im feeling generous heres a holiday classic fo...      0     0    0
# 5322                     i feel like it dirty src http i      0     0    0
# 12219               i feel dirty srcurl http draftbloger      0     0    0
# 14581  i feel all kinds of dirty and not a good dirty...      0     0    0
#
#        love  sadness  surprise
# 5156      1        0         0
# 5322      0        1         0
# 12219     0        1         0
# 14581     0        1         0

# %%
tok_ids = train_df["text"].str.contains(r"(?: src(?: url)?)", regex=True)
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('src').str[0]
train_df.loc[tok_ids, 'text'] = train_df[tok_ids]['text'].str.split('srcurl').str[0]

# %% [markdown]
# ### Finding a good regex for links to substitute with [LINK]

# %%
occ = train_df[train_df["text"].str.contains(r"(?: \bhref\b)", regex=True)]
occ
# Out:
#                                                     text  anger  fear  joy  \
# 323    i stopped feeling so exhausted a href http pro...      0     0    0
# 462                  i feel so dazed a href http twitter      0     0    0
# 866    i feel unwelcome at work sometimes and think p...      0     0    0
# 967                         i a href http feeling groggy      0     0    0
# 1162   i really feel that we are progressing towards ...      0     0    1
# ...                                                  ...    ...   ...  ...
# 15344  i feel more confident already a href http john...      0     0    1
# 15518  i feel honoured to be asked thanks a href http...      0     0    1
# 15732  i feel like it was just a title mimm fall insp...      0     0    1
# 15779  i cant always identify with peoples struggles ...      0     0    0
# 15784  i get the added bonus of feeling superior and ...      0     0    1
#
#        love  sadness  surprise
# 323       0        1         0
# 462       0        0         1
# 866       0        1         0
# 967       0        1         0
# 1162      0        0         0
# ...     ...      ...       ...
# 15344     0        0         0
# 15518     0        0         0
# 15732     0        0         0
# 15779     0        1         0
# 15784     0        0         0
#
# [157 rows x 7 columns]

# %%
train_df["text"].str.contains(r"(?: a href)", regex=True).sum()
# Out:
# 135

# %%
train_df["text"].str.contains(r"(?: a href https?)", regex=True).sum()
# Out:
# 134

# %%
train_df["text"].str.contains(r"(?: href https?)", regex=True).sum()
# Out:
# 155

# %%
train_df["text"].str.contains(r"(?: a href http www)", regex=True).sum()
# Out:
# 31

# %%
train_df["text"].str.contains(r"(?: \bwww\b)", regex=True).sum()
# Out:
# 44

# %%
link_regex = r"(?: (?: (?:a |link ))?href https?(?: \w+|$))"
train_df["text"].str.contains(link_regex, regex=True).sum()
# Out:
# 155

# %%
regex_ids = train_df["text"].str.contains(link_regex, regex=True)
occ = train_df["text"].str.contains(r"(?: \bhref\b)", regex=True)
(regex_ids & occ).sum()
# Out:
# 155

# %%
train_df["text"] = train_df["text"].str.replace(link_regex, '[LINK]', regex=True)

# %% [markdown]
# ### Same for validation and test

# %%
occ = val_df[val_df["text"].str.contains(r"(?: nofollow)", regex=True)]
occ
# Out:
#                                                    text  anger  fear  joy  \
# 679   i like to show the homeowners these catalogs t...      0     0    0
# 1848  i feel like it title share on reddit reddit a ...      0     0    0
#
#       love  sadness  surprise
# 679      0        1         0
# 1848     0        1         0

# %% [markdown]
# in this sample, a is always used to start metadata

# %%
# cut sentences from the specified tokens
tok_ids = val_df["text"].str.contains(r"(?: (?: ^|\b)nofollow(?: $|\b))", regex=True)
val_df.loc[tok_ids, 'text'] = val_df[tok_ids]['text'].str.split('a').str[0]

# %%
occ = val_df[val_df["text"].str.contains(r"(?: \bscript\b)", regex=True)]
occ
# Out:
# Empty DataFrame
# Columns: [text, anger, fear, joy, love, sadness, surprise]
# Index: []

# %%
occ = val_df[val_df["text"].str.contains(r"(?: img)", regex=True)]
occ
# Out:
# Empty DataFrame
# Columns: [text, anger, fear, joy, love, sadness, surprise]
# Index: []

# %%
occ = val_df[val_df["text"].str.contains(r"(?: title bookmark)", regex=True)]
occ
# Out:
# Empty DataFrame
# Columns: [text, anger, fear, joy, love, sadness, surprise]
# Index: []

# %%
occ = val_df[val_df["text"].str.contains(r"(?: src(?: url)?)", regex=True)]
occ
# Out:
#                                                   text  anger  fear  joy  \
# 101  im feeling nostalgic cant beat the corys ifram...      0     0    0
#
#      love  sadness  surprise
# 101     1        0         0

# %%
tok_ids = val_df["text"].str.contains(r"(?: src(?: url)?)", regex=True)
val_df.loc[tok_ids, 'text'] = val_df[tok_ids]['text'].str.split('src').str[0]

# %%
occ = val_df[val_df["text"].str.contains(r"(?: \bhref\b)", regex=True)]
occ
# Out:
#                                                    text  anger  fear  joy  \
# 56    i feel sometimes i am like heartless tin woodm...      1     0    0
# 63    i feel perfect with you on facebook href http www      0     0    1
# 386   i feel so embarrassed and humiliated korean at...      0     0    0
# 403   i dolphins feel sweet taste of victory defeat ...      0     0    1
# 449   i feel much more comfortable finding those peo...      0     0    1
# 579                     i feel loyal to a href http www      0     0    0
# 581   i still feel horny from that little a href htt...      0     0    0
# 666            i feel horny a class arialblue href chat      0     0    0
# 674   i feel so amazing and i m so by a href http yo...      0     0    1
# 706          i feel sorry for a href http bluestarlight      0     0    0
# 1005  i am feeling all nostalgic i went on pinterest...      0     0    0
# 1234  i feel pretty a href http unspokenwords keptin...      0     0    1
# 1274  i am going to several holiday parties and i ca...      0     0    1
# 1315  i get a day off from writing and feeling press...      0     0    0
# 1335  im still a little mixed on how i feel about hi...      0     0    0
# 1346  i feel stumble a class content link href https...      0     0    1
# 1470  i assure you marilla that i feel like praying ...      0     0    1
# 1551  i have posted thus far and keep up with what e...      0     0    1
# 1692  i feel isolated and overwhelmed this lie can c...      0     0    0
# 1697               i feel horny tonight a href http www      0     0    0
# 1751  i was feeling hesitant to part with any more m...      0     1    0
# 1770  i feel a little vain i guess but last time i d...      0     0    0
#
#       love  sadness  surprise
# 56       0        0         0
# 63       0        0         0
# 386      0        1         0
# 403      0        0         0
# 449      0        0         0
# 579      1        0         0
# 581      1        0         0
# 666      1        0         0
# 674      0        0         0
# 706      0        1         0
# 1005     1        0         0
# 1234     0        0         0
# 1274     0        0         0
# 1315     0        0         1
# 1335     1        0         0
# 1346     0        0         0
# 1470     0        0         0
# 1551     0        0         0
# 1692     0        1         0
# 1697     1        0         0
# 1751     0        0         0
# 1770     0        1         0

# %%
link_regex = r"(?: (?: (?:a |link ))?href(?: https?)?(?: \w+|$))"
val_df["text"].str.contains(link_regex, regex=True).sum()
# Out:
# 22

# %%
regex_ids = val_df["text"].str.contains(link_regex, regex=True)
occ = val_df["text"].str.contains(r"(?: \bhref\b)", regex=True)
(regex_ids & occ).sum()
# Out:
# 22

# %%
val_df["text"] = val_df["text"].str.replace(link_regex, '[LINK]', regex=True)

# %%
occ = test_df[test_df["text"].str.contains(r"(?: nofollow)", regex=True)]
occ
# Out:
#                                                   text  anger  fear  joy  \
# 806  i feel the earth move tribute to carole king k...      0     0    0
#
#      love  sadness  surprise
# 806     0        1         0

# %% [markdown]
# in this sample, a is always used to start metadata

# %%
# cut sentences from the specified tokens
tok_ids = test_df["text"].str.contains(r"(?: (?: ^|\b)nofollow(?: $|\b))", regex=True)
test_df.loc[tok_ids, 'text'] = test_df[tok_ids]['text'].str.split('rel').str[0]

# %%
occ = test_df[test_df["text"].str.contains(r"(?: \bscript\b)", regex=True)]
occ
# Out:
#                                                   text  anger  fear  joy  \
# 164  i just went about my script of would you like ...      0     1    0
# 270  i didnt feel i rushed things dhawan tweet scri...      1     0    0
# 907  i dropped off the script and left feeling diss...      1     0    0
#
#      love  sadness  surprise
# 164     0        0         0
# 270     0        0         0
# 907     0        0         0

# %%
tok_ids = test_df["text"].str.contains(r"(?: \bscript\b)", regex=True)
test_df.loc[tok_ids, 'text'] = test_df[tok_ids]['text'].str.split('tweet').str[0]

# %%
occ = test_df[test_df["text"].str.contains(r"(?: img)", regex=True)]
occ
# Out:
# Empty DataFrame
# Columns: [text, anger, fear, joy, love, sadness, surprise]
# Index: []

# %%
occ = test_df[test_df["text"].str.contains(r"(?: title bookmark)", regex=True)]
occ
# Out:
#                                                    text  anger  fear  joy  \
# 1548  i feel it like you target blank class di title...      0     0    0
#
#       love  sadness  surprise
# 1548     0        1         0

# %%
tok_ids = test_df["text"].str.contains(r"(?: title bookmark)", regex=True)
test_df.loc[tok_ids, 'text'] = test_df[tok_ids]['text'].str.split('target').str[0]

# %%
occ = test_df[test_df["text"].str.contains(r"(?: src(?: url)?)", regex=True)]
occ#TODO what is this thing?
# Out:
#                                                   text  anger  fear  joy  \
# 779  i input class size medium wp image height src ...      0     0    1
#
#      love  sadness  surprise
# 779     0        0         0

# %%
occ = test_df[test_df["text"].str.contains(r"(?: \bhref\b)", regex=True)]
occ
# Out:
#                                                    text  anger  fear  joy  \
# 33                     i feel so cold a href http irish      1     0    0
# 52    i feel like i could go into any situation and ...      0     0    1
# 99    i was still feeling weepy and strung out so ma...      0     0    0
# 154   i really like this person feel that the questi...      0     0    1
# 176   i feel brave today heading to amman and beirut...      0     0    1
# 288   i feel pretty much like this scene from a href...      0     0    1
# 375   im feeling a lot less ugly duckling and a lot ...      0     0    0
# 426   i feel unprotected a class post count link hre...      0     0    0
# 511   i feel i have to give credit to jen mitchell f...      0     0    1
# 773   ive also had a nosy on the website and seeing ...      0     0    1
# 808   i can t say for certain why but it actually ma...      0     0    1
# 952                 im feeling jolly by a href http www      0     0    1
# 1001  i feel honoured today olu jacobs i feel honour...      0     0    1
# 1039  ill find that elusive second wind and feel mor...      0     0    1
# 1146  i feel affirmed gracious sensuous and will hav...      0     0    0
# 1223  i exactly feel whenever i feel lonely or depre...      0     0    0
# 1259         i feel useless a href http juliemadblogger      0     0    0
# 1494  i feel like an ungrateful ass a href http this...      0     0    0
# 1602     im feeling cranky a href http doingaone eighty      1     0    0
# 1646            i feel special a href http facsimilogos      0     0    1
# 1658  i feel numb the end of the world as we know it...      0     0    0
# 1855  i really need to find my nitch up here in vt i...      0     0    0
# 1958                     im feeling playful a href http      0     0    1
#
#       love  sadness  surprise
# 33       0        0         0
# 52       0        0         0
# 99       0        1         0
# 154      0        0         0
# 176      0        0         0
# 288      0        0         0
# 375      0        1         0
# 426      0        1         0
# 511      0        0         0
# 773      0        0         0
# 808      0        0         0
# 952      0        0         0
# 1001     0        0         0
# 1039     0        0         0
# 1146     1        0         0
# 1223     0        1         0
# 1259     0        1         0
# 1494     0        1         0
# 1602     0        0         0
# 1646     0        0         0
# 1658     0        1         0
# 1855     0        1         0
# 1958     0        0         0

# %%
link_regex = r"(?: (?: (?:a |link ))?href(?: https?)?(?: \w+|$))"
test_df["text"].str.contains(link_regex, regex=True).sum()
# Out:
# 23

# %%
regex_ids = test_df["text"].str.contains(link_regex, regex=True)
occ = test_df["text"].str.contains(r"(?: \bhref\b)", regex=True)
(regex_ids & occ).sum()
# Out:
# 23

# %%
test_df["text"] = test_df["text"].str.replace(link_regex, '[LINK]', regex=True)

# %%
# remove long sequences of same character (max 5)
train_df['text'] = train_df['text'].str.replace(r'(.)\1{5,}', r'\1\1\1\1\1', regex=True)
val_df['text'] = val_df['text'].str.replace(r'(.)\1{5,}', r'\1\1\1\1\1', regex=True)#TODO test?

# %%
OUT_DIR = "./dataset/TwitterDataCleaned/"

# %%
# Save the cleaned dataset
if not os.path.exists(OUT_DIR):
    os.makedirs(OUT_DIR)
train_df.to_csv(OUT_DIR + "train.tsv", sep='\t', index=False)
val_df.to_csv(OUT_DIR + "val.tsv", sep='\t', index=False)
test_df.to_csv(OUT_DIR + "test.tsv", sep='\t', index=False)
